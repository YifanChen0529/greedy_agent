# %%
import numpy as np
import matplotlib
import pandas as pd

import matplotlib.pyplot as plt




df_all_pure = []
df_all_greedy = []
for i in range(5):
    df_all_pure.append(pd.read_csv('lio/results/er%d/er2_1_bignum_det/log.csv'%(i+1)))
    # df_all_greedy.append(pd.read_csv('lio/results/er%d/er2_1_greedy_det/log.csv'%(i+1)))

signal1= []
signal2= []


t = df_all_pure[0]['episode']
for df in df_all_pure:
    signal1.append(df['A1_reward_total'])
    signal2.append(df['A2_reward_total'])

# for df in df_all_greedy:
#     signal1.append(df['A1_reward_total'] + df['A2_reward_total'])


mins1 = np.min(signal1, axis=0)
maxs1 = np.max(signal1, axis=0)
means1 = np.mean(signal1, axis=0)

mins2 = np.min(signal2, axis=0)
maxs2 = np.max(signal2, axis=0)
means2 = np.mean(signal2, axis=0)



plt.figure(figsize=(7, 4))
plt.fill_between(t, mins1, maxs1, alpha=0.3, color='tab:green')
plt.plot(t, means1, color='tab:green', label='Adversary', linewidth=1)

plt.fill_between(t, mins2, maxs2, alpha=0.3, color='tab:orange' )
plt.plot(t, means2, color='tab:orange', label='Coopertor', linewidth=1)


plt.grid(color = 'silver', linestyle = '--', linewidth = 0.3)

plt.xlabel('Episode',fontsize=18)
plt.ylabel('Each Agent Reward',fontsize=18)
plt.title('ER(2,1) ',fontsize=18)
plt.legend(title='Agent', title_fontsize = 14, loc='best')
plt.show()

# %%
import numpy as np
import matplotlib
import pandas as pd

import matplotlib.pyplot as plt




df_all_pure = []
df_all_greedy = []
for i in range(5):
    df_all_pure.append(pd.read_csv('lio/results/er%d/er2_1_bignum_det/log.csv'%(i+1)))
    # df_all_greedy.append(pd.read_csv('lio/results/er%d/er2_1_greedy_det/log.csv'%(i+1)))

signal1= []
signal2= []


t = df_all_pure[0]['episode']
for df in df_all_pure:
    signal1.append(df['A1_win_rate'])
    # signal2.append(df['A2_reward_total'])

# for df in df_all_greedy:
#     signal1.append(df['A1_reward_total'] + df['A2_reward_total'])


mins1 = np.min(signal1, axis=0)
maxs1 = np.max(signal1, axis=0)
means1 = np.mean(signal1, axis=0)




plt.figure(figsize=(7, 4))
plt.fill_between(t, mins1, maxs1, alpha=0.3, color='tab:red')
plt.plot(t, means1, color='tab:red', label='Adversary', linewidth=1)



plt.grid(color = 'silver', linestyle = '--', linewidth = 0.3)

plt.xlabel('Episode',fontsize=18)
plt.ylabel('Success rate(%)',fontsize=18)
plt.title('ER(2,1) ',fontsize=18)
# plt.legend(title='Agent', title_fontsize = 14, loc='best')
plt.show()

# %%
import numpy as np
import matplotlib
import pandas as pd

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset



df_all_pure = []
df_all_greedy = []
for i in range(5):
    df_all_pure.append(pd.read_csv('lio/results/er%d/er4_2_bignum_det/log.csv'%(i+1)))
    # df_all_greedy.append(pd.read_csv('lio/results/er%d/er2_1_greedy_det/log.csv'%(i+1)))

signal1= []
signal2= []
signal3= []
signal4= []


t = df_all_pure[0]['episode']
for df in df_all_pure:
    signal1.append(df['A1_reward_total'])
    signal2.append(df['A2_reward_total'])
    signal3.append(df['A3_reward_total'])
    signal4.append(df['A4_reward_total'])

# for df in df_all_greedy:
#     signal1.append(df['A1_reward_total'] + df['A2_reward_total'])


mins1 = np.min(signal1, axis=0)
maxs1 = np.max(signal1, axis=0)
means1 = np.mean(signal1, axis=0)

mins2 = np.min(signal2, axis=0)
maxs2 = np.max(signal2, axis=0)
means2 = np.mean(signal2, axis=0)

mins3 = np.min(signal3, axis=0)
maxs3 = np.max(signal3, axis=0)
means3 = np.mean(signal3, axis=0)

mins4 = np.min(signal4, axis=0)
maxs4 = np.max(signal4, axis=0)
means4 = np.mean(signal4, axis=0)

fig,ax = plt.subplots(figsize=(7,4))






ax.fill_between(t, mins1, maxs1, alpha=0.3, color='tab:green')
ax.plot(t, means1, color='tab:green', label='Adversary', linewidth=1)

ax.fill_between(t, mins2, maxs2, alpha=0.3, color='tab:orange' )
ax.plot(t, means2, color='tab:orange', label='Coopertor', linewidth=1)
ax.fill_between(t, mins3, maxs3, alpha=0.3, color='tab:orange' )
ax.plot(t, means3, color='tab:orange', label='Coopertor', linewidth=1)
ax.fill_between(t, mins4, maxs4, alpha=0.3, color='tab:orange' )
ax.plot(t, means4, color='tab:orange', label='Coopertor', linewidth=1)


ax.grid(color = 'silver', linestyle = '--', linewidth = 0.3)

ax.set_xlabel('Episode',fontsize=18)
ax.set_ylabel('Each Agent Reward',fontsize=18)
ax.set_title('ER(4,2) and ER(4,3)',fontsize=18)
ax.legend(title='Agent', title_fontsize = 14, loc='best')


# axins1 = zoomed_inset_axes(ax, zoom = 0.5, loc=1)
axins1 = inset_axes(ax, 2.5,1.5 , loc=1,bbox_to_anchor=(0.5, 0.8),bbox_transform=ax.figure.transFigure) # no zoom
axins1.fill_between(t, mins2, maxs2, alpha=0.3, color='tab:orange' )
axins1.plot(t, means2, color='tab:orange', label='Coopertor', linewidth=1)
axins1.fill_between(t, mins3, maxs3, alpha=0.3, color='tab:orange' )
axins1.plot(t, means3, color='tab:orange', label='Coopertor', linewidth=1)
axins1.fill_between(t, mins4, maxs4, alpha=0.3, color='tab:orange' )
axins1.plot(t, means4, color='tab:orange', label='Coopertor', linewidth=1)

# SPECIFY THE LIMITS
x1, x2, y1, y2 = 0,2000,20,60 
axins1.set_xlim(x1, x2)
axins1.set_ylim(y1, y2)

mark_inset(ax, axins1, loc1=2, loc2=3, fc="none", ec="0.5")
# Out:
# (<mpl_toolkits.axes_grid1.inset_locator.BboxPatch at 0x7fa701b87a30>,
# ...
#  <mpl_toolkits.axes_grid1.inset_locator.BboxConnector at 0x7fa701b87f70>)

# %%
import numpy as np
import matplotlib
import pandas as pd

import matplotlib.pyplot as plt




df_all_pure = []
df_all_greedy = []
for i in range(5):
    df_all_pure.append(pd.read_csv('lio/results/er%d/er4_2_bignum_det/log.csv'%(i+1)))
    # df_all_greedy.append(pd.read_csv('lio/results/er%d/er2_1_greedy_det/log.csv'%(i+1)))

signal1= []
signal2= []


t = df_all_pure[0]['episode']
for df in df_all_pure:
    signal1.append(df['A1_win_rate'])
    # signal2.append(df['A2_reward_total'])

# for df in df_all_greedy:
#     signal1.append(df['A1_reward_total'] + df['A2_reward_total'])


mins1 = np.min(signal1, axis=0)
maxs1 = np.max(signal1, axis=0)
means1 = np.mean(signal1, axis=0)




plt.figure(figsize=(7, 4))
plt.fill_between(t, mins1, maxs1, alpha=0.3, color='tab:red')
plt.plot(t, means1, color='tab:red', label='Adversary', linewidth=1)



plt.grid(color = 'silver', linestyle = '--', linewidth = 0.3)

plt.xlabel('Episode',fontsize=18)
plt.ylabel('Success rate(%)',fontsize=18)
plt.title('ER(4,2) and ER(4,3) ',fontsize=18)
# plt.legend(title='Agent', title_fontsize = 14, loc='best')
plt.show()

# %%
import numpy as np
import matplotlib
import pandas as pd

import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset



df_all_pure = []
df_all_greedy = []
for i in range(5):
    df_all_pure.append(pd.read_csv('lio/results/er%d/er4_2_bignum_det/log.csv'%(i+1)))
    # df_all_greedy.append(pd.read_csv('lio/results/er%d/er2_1_greedy_det/log.csv'%(i+1)))

signal1= []
signal2= []


t = df_all_pure[0]['episode']
for df in df_all_pure:
    signal1.append(df['A1_win_rate'])
    # signal2.append(df['A2_reward_total'])

# for df in df_all_greedy:
#     signal1.append(df['A1_reward_total'] + df['A2_reward_total'])


mins1 = np.min(signal1, axis=0)
maxs1 = np.max(signal1, axis=0)
means1 = np.mean(signal1, axis=0)




# plt.figure(figsize=(7, 4))
fig,ax = plt.subplots(figsize=(7,4))



ax.fill_between(t, mins1, maxs1, alpha=0.3, color='tab:red')
ax.plot(t, means1, color='tab:red', label='Adversary', linewidth=1)



ax.grid(color = 'silver', linestyle = '--', linewidth = 0.3)

ax.set_xlabel('Episode',fontsize=18)
ax.set_ylabel('Success rate(%)',fontsize=18)
ax.set_title('ER(4,2) and ER(4,3) ',fontsize=18)
# plt.legend(title='Agent', title_fontsize = 14, loc='best')


# axins1 = zoomed_inset_axes(ax, zoom = 0.5, loc=1)
axins1 = inset_axes(ax, 2.5,1.5 , loc=1,bbox_to_anchor=(0.8, 0.8),bbox_transform=ax.figure.transFigure) # no zoom
# axins1.plot(t,datapts.T)
axins1.fill_between(t, mins1, maxs1, alpha=0.3, color='tab:red')
axins1.plot(t, means1, color='tab:red', label='Adversary', linewidth=1)

# SPECIFY THE LIMITS
x1, x2, y1, y2 = 0,2000,0,100 
axins1.set_xlim(x1, x2)
axins1.set_ylim(y1, y2)

mark_inset(ax, axins1, loc1=2, loc2=3, fc="none", ec="0.5")
# Out:
# (<mpl_toolkits.axes_grid1.inset_locator.BboxPatch at 0x7fa181ba4d90>,
# ...
#  <mpl_toolkits.axes_grid1.inset_locator.BboxConnector at 0x7fa181adcfa0>)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

datapts = np.array([[22.51, 27.99, 27.3 , 39.55],
                    [28.23, 28.01, 35.34, 54.78],
                    [36.87, 36.87, 42.57, 55.54],
                    [38.47, 43.13, 49.08, 55.76]])


x = [5,10,15,20]
xlabs = ["5","10","15","20"]
y = [10,15,20,25]
ylabs = ["10","15","20","25"] 





fig,ax = plt.subplots(figsize=(10,10))
ax.plot(y,datapts.T)
ax.plot(y,datapts.T,'yo')
ax.legend(xlabs,title='CURRENT (A)', loc='upper right')
ax.set_xlabel('RESISTANCE (OHM)')
ax.set_ylabel('VOLTAGE (V)')
ax.set_xticks(ticks=y)
ax.set_xticklabels(labels=ylabs)
ax.set_xlim([5,30])











# loc values
# 2---8---1
# |   |   |
# 6---10--5/7
# |   |   |
# 3---9---4

axins1 = zoomed_inset_axes(ax, zoom = 5, loc=2)
axins1.plot(y,datapts.T)
axins1.plot(y,datapts.T,'mo')

# SPECIFY THE LIMITS
x1, x2, y1, y2 = 24,26,54.5,56 
axins1.set_xlim(x1, x2)
axins1.set_ylim(y1, y2)

# FOR ANNOTATING THE 3 POINTS WE ARE ZOOMING ON
for dpt,ypt in zip(datapts.T[3],[25]*4):
    if dpt > y1 and dpt < y2:
        axins1.annotate("%.2f"%(dpt),xy=(ypt,dpt),textcoords='data')
        
# IF SET TO TRUE, TICKS ALONG 
# THE TWO AXIS WILL BE VISIBLE
plt.xticks(visible=False)
plt.yticks(visible=False)

mark_inset(ax, axins1, loc1=1, loc2=4, fc="none", ec="0.5")
# Out:
# (<mpl_toolkits.axes_grid1.inset_locator.BboxPatch at 0x7fa18df60850>,
# ...
#  <mpl_toolkits.axes_grid1.inset_locator.BboxConnector at 0x7fa18def0d90>)
