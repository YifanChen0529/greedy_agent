# %%
import numpy as np
import matplotlib
import pandas as pd

import matplotlib.pyplot as plt




df_all_pure = []
df_all_greedy = []
for i in range(5):
    df_all_pure.append(pd.read_csv('lio/results/er%d/policy_test_toggle/log.csv'%(i+1)))
    # df_all_greedy.append(pd.read_csv('lio/results/er%d/er2_1_greedy_det/log.csv'%(i+1)))

signal1= []
signal2= []


t = df_all_pure[0]['episode']
for df in df_all_pure:
    signal1.append(df['A1_reward_total'] )
    signal2.append(df['A2_reward_total'])

# for df in df_all_greedy:
#     signal1.append(df['A1_reward_total'] + df['A2_reward_total'])


mins1 = np.min(signal1, axis=0)
maxs1 = np.max(signal1, axis=0)
means1 = np.mean(signal1, axis=0)

mins2 = np.min(signal2, axis=0)
maxs2 = np.max(signal2, axis=0)
means2 = np.mean(signal2, axis=0)



plt.figure(figsize=(7, 4))
plt.fill_between(t, mins1, maxs1, alpha=0.3, color='tab:blue')
plt.plot(t, means1, color='tab:blue', label='Adversary', linewidth=1)

plt.fill_between(t, mins2, maxs2, alpha=0.3, color='tab:orange' )
plt.plot(t, means2, color='tab:orange', label='Coopertor', linewidth=1)


plt.grid(color = 'silver', linestyle = '--', linewidth = 0.3)

plt.xlabel('Episode',fontsize=18)
plt.ylabel('Each Agent Reward',fontsize=18)
plt.title('ER(2,1) ',fontsize=18)
plt.legend(title='Agent ', title_fontsize = 14, loc='best')
plt.show()

# %%
# episode,step_train,step,A1_reward_total,A1_n_lever,A1_n_door,A1_received,A1_given,A1_r-lever,A1_r-start,A1_r-door,A1_win_rate,A2_reward_total,A2_n_lever,A2_n_door,A2_received,A2_given,A2_r-lever,A2_r-start,A2_r-door,A2_win_rate,steps_per_eps

import numpy as np
import matplotlib
import pandas as pd

import matplotlib.pyplot as plt




df_all_pure = []
df_all_greedy = []
for i in range(5):
    df_all_pure.append(pd.read_csv('lio/results/er%d/policy_test_toggle/log.csv'%(i+1)))
    # df_all_greedy.append(pd.read_csv('lio/results/er%d/er2_1_greedy_det/log.csv'%(i+1)))

signal1= []
signal2= []


t = df_all_pure[0]['episode']
for df in df_all_pure:
    signal1.append(df['A1_given'] )
    signal2.append(df['A1_received'])

# for df in df_all_greedy:
#     signal1.append(df['A1_reward_total'] + df['A2_reward_total'])


mins1 = np.min(signal1, axis=0)
maxs1 = np.max(signal1, axis=0)
means1 = np.mean(signal1, axis=0)

mins2 = np.min(signal2, axis=0)
maxs2 = np.max(signal2, axis=0)
means2 = np.mean(signal2, axis=0)



plt.figure(figsize=(7, 4))
plt.fill_between(t, mins1, maxs1, alpha=0.3, color='tab:blue')
plt.plot(t, means1, color='tab:blue', label='A1_given', linewidth=1)

plt.fill_between(t, mins2, maxs2, alpha=0.3, color='tab:orange' )
plt.plot(t, means2, color='tab:orange', label='A1_received', linewidth=1)


plt.grid(color = 'silver', linestyle = '--', linewidth = 0.3)

plt.xlabel('Episode',fontsize=18)
plt.ylabel('reward',fontsize=18)
plt.title('ER(2,1) ',fontsize=18)
plt.legend(title='incentive reward ', title_fontsize = 14, loc='best')
plt.show()
# Out:
# /home/shb/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
import numpy as np
import matplotlib
import pandas as pd

import matplotlib.pyplot as plt




df_all_pure = []
df_all_greedy = []
for i in range(5):
    df_all_pure.append(pd.read_csv('lio/results/er%d/er4_2_noaction_det/log.csv'%(i+1)))
    # df_all_greedy.append(pd.read_csv('lio/results/er%d/er2_1_greedy_det/log.csv'%(i+1)))

signal1= []
signal2= []
signal3= []
signal4= []


t = df_all_pure[0]['episode']
for df in df_all_pure:
    signal1.append(df['A1_reward_total'] )
    signal2.append(df['A2_reward_total'])
    signal3.append(df['A3_reward_total'])
    signal4.append(df['A4_reward_total'])

# for df in df_all_greedy:
#     signal1.append(df['A1_reward_total'] + df['A2_reward_total'])


mins1 = np.min(signal1, axis=0)
maxs1 = np.max(signal1, axis=0)
means1 = np.mean(signal1, axis=0)

mins2 = np.min(signal2, axis=0)
maxs2 = np.max(signal2, axis=0)
means2 = np.mean(signal2, axis=0)

mins3 = np.min(signal3, axis=0)
maxs3 = np.max(signal3, axis=0)
means3 = np.mean(signal3, axis=0)

mins4 = np.min(signal4, axis=0)
maxs4 = np.max(signal4, axis=0)
means4 = np.mean(signal4, axis=0)



plt.figure(figsize=(7, 4))
plt.fill_between(t, mins1, maxs1, alpha=0.3, color='tab:blue')
plt.plot(t, means1, color='tab:blue', label='Adversary', linewidth=1)

plt.fill_between(t, mins2, maxs2, alpha=0.3, color='tab:orange' )
plt.plot(t, means2, color='tab:orange', label='Coopertor', linewidth=1)
plt.fill_between(t, mins3, maxs3, alpha=0.3, color='tab:orange' )
plt.plot(t, means3, color='tab:orange', label='Coopertor', linewidth=1)
plt.fill_between(t, mins4, maxs4, alpha=0.3, color='tab:orange' )
plt.plot(t, means4, color='tab:orange', label='Coopertor', linewidth=1)


plt.grid(color = 'silver', linestyle = '--', linewidth = 0.3)

plt.xlabel('Episode',fontsize=18)
plt.ylabel('Each Agent Reward',fontsize=18)
plt.title('ER(4,2) ',fontsize=18)
plt.legend(title='Agent ', title_fontsize = 14, loc='best')
plt.show()

# %%
import numpy as np
import matplotlib
import pandas as pd

import matplotlib.pyplot as plt




df_all_pure = []
df_all_greedy = []
for i in range(5):
    df_all_pure.append(pd.read_csv('lio/results/er%d/er4_3_noaction_det/log.csv'%(i+1)))
    # df_all_greedy.append(pd.read_csv('lio/results/er%d/er2_1_greedy_det/log.csv'%(i+1)))

signal1= []
signal2= []
signal3= []
signal4= []


t = df_all_pure[0]['episode']
for df in df_all_pure:
    signal1.append(df['A1_reward_total'] )
    signal2.append(df['A2_reward_total'])
    signal3.append(df['A3_reward_total'])
    signal4.append(df['A4_reward_total'])

# for df in df_all_greedy:
#     signal1.append(df['A1_reward_total'] + df['A2_reward_total'])


mins1 = np.min(signal1, axis=0)
maxs1 = np.max(signal1, axis=0)
means1 = np.mean(signal1, axis=0)

mins2 = np.min(signal2, axis=0)
maxs2 = np.max(signal2, axis=0)
means2 = np.mean(signal2, axis=0)

mins3 = np.min(signal3, axis=0)
maxs3 = np.max(signal3, axis=0)
means3 = np.mean(signal3, axis=0)

mins4 = np.min(signal4, axis=0)
maxs4 = np.max(signal4, axis=0)
means4 = np.mean(signal4, axis=0)



plt.figure(figsize=(7, 4))
plt.fill_between(t, mins1, maxs1, alpha=0.3, color='tab:blue')
plt.plot(t, means1, color='tab:blue', label='Adversary', linewidth=1)

plt.fill_between(t, mins2, maxs2, alpha=0.3, color='tab:orange' )
plt.plot(t, means2, color='tab:orange', label='Coopertor', linewidth=1)
plt.fill_between(t, mins3, maxs3, alpha=0.3, color='tab:orange' )
plt.plot(t, means3, color='tab:orange', label='Coopertor', linewidth=1)
plt.fill_between(t, mins4, maxs4, alpha=0.3, color='tab:orange' )
plt.plot(t, means4, color='tab:orange', label='Coopertor', linewidth=1)


plt.grid(color = 'silver', linestyle = '--', linewidth = 0.3)

plt.xlabel('Episode',fontsize=18)
plt.ylabel('Each Agent Reward',fontsize=18)
plt.title('ER(4,3) ',fontsize=18)
plt.legend(title='Agent ', title_fontsize = 14, loc='best')
plt.show()

# %%
import numpy as np
import matplotlib
import pandas as pd

import matplotlib.pyplot as plt




df_all_pure = []
df_all_greedy = []
for i in range(5):
    df_all_pure.append(pd.read_csv('lio/results/er%d/er4_3_noaction_det/log.csv'%(i+1)))
    # df_all_greedy.append(pd.read_csv('lio/results/er%d/er2_1_greedy_det/log.csv'%(i+1)))

signal1= []
signal2= []


t = df_all_pure[0]['episode']
for df in df_all_pure:
    signal1.append(df['A1_win_rate'])
    # signal2.append(df['A2_reward_total'])

# for df in df_all_greedy:
#     signal1.append(df['A1_reward_total'] + df['A2_reward_total'])


mins1 = np.min(signal1, axis=0)
maxs1 = np.max(signal1, axis=0)
means1 = np.mean(signal1, axis=0)




plt.figure(figsize=(7, 4))
plt.fill_between(t, mins1, maxs1, alpha=0.3, color='tab:red')
plt.plot(t, means1, color='tab:red', label='Adversary', linewidth=1)



plt.grid(color = 'silver', linestyle = '--', linewidth = 0.3)

plt.xlabel('Episode',fontsize=18)
plt.ylabel('Success rate(%)',fontsize=18)
plt.title('ER(4,3) and ER(2,1) ',fontsize=18)
# plt.legend(title='Agent', title_fontsize = 14, loc='best')
plt.show()

# %%
import numpy as np
import matplotlib
import pandas as pd

import matplotlib.pyplot as plt




df_all_pure = []
df_all_greedy = []
for i in range(5):
    df_all_pure.append(pd.read_csv('lio/results/er%d/er4_2_noaction_det/log.csv'%(i+1)))
    df_all_greedy.append(pd.read_csv('lio/results/er%d/er4_3_noaction_det/log.csv'%(i+1)))

signal1= []
signal2= []


t = df_all_pure[0]['episode']
for df in df_all_pure:
    signal1.append(df['A1_win_rate'])
    # signal2.append(df['A2_reward_total'])

for df in df_all_greedy:
    signal2.append(df['A1_win_rate'])

mins1 = np.min(signal1, axis=0)
maxs1 = np.max(signal1, axis=0)
means1 = np.mean(signal1, axis=0)


mins2 = np.min(signal2, axis=0)
maxs2 = np.max(signal2, axis=0)
means2 = np.mean(signal2, axis=0)




plt.figure(figsize=(7, 4))
plt.fill_between(t, mins1, maxs1, alpha=0.3, color='tab:red')
plt.plot(t, means1, color='tab:red', label='ER(4,2)', linewidth=1)

plt.fill_between(t, mins2, maxs2, alpha=0.3, color='tab:blue')
plt.plot(t, means2, color='tab:blue', label='ER(4,3)', linewidth=1)

plt.fill_between(t, mins2, maxs2, alpha=0.3, color='tab:green')
plt.plot(t, means2, color='tab:green', label='ER(2,1)', linewidth=1)



plt.grid(color = 'silver', linestyle = '--', linewidth = 0.3)

plt.xlabel('Episode',fontsize=18)
plt.ylabel('Success rate(%)',fontsize=18)
plt.title('Bypass Policy',fontsize=18)
plt.legend(title='Environment', title_fontsize = 14, loc='best')
plt.show()
